# %%
import numpy as np

population_t = np.random.rand(100)
idx = np.argsort(population_t)

# %%
population_t[idx]
# Out:
# array([0.00137789, 0.00220622, 0.00294709, 0.01192526, 0.0199635 ,
#        0.03083371, 0.0401722 , 0.04755945, 0.07422919, 0.11426684,
#        0.11570772, 0.11876012, 0.1198472 , 0.13327398, 0.13898694,
#        0.14269925, 0.15624265, 0.16243171, 0.16495162, 0.18084787,
#        0.18176968, 0.18760334, 0.19330201, 0.19857108, 0.19968966,
#        0.20080703, 0.20210217, 0.20775223, 0.22311577, 0.22947542,
#        0.26316224, 0.27133517, 0.28399884, 0.28698687, 0.29325081,
#        0.29344335, 0.29523554, 0.32645547, 0.33669842, 0.34715332,
#        0.36327298, 0.36340676, 0.38253843, 0.38992324, 0.4089132 ,
#        0.41646783, 0.42661582, 0.42661972, 0.44151293, 0.44202508,
#        0.44645762, 0.44974344, 0.45731029, 0.46211723, 0.46903952,
#        0.4786907 , 0.485158  , 0.48838457, 0.4951909 , 0.50117441,
#        0.52740572, 0.55770108, 0.55848335, 0.56146619, 0.56587609,
#        0.58462119, 0.59325852, 0.59627416, 0.61011172, 0.61176046,
# ...
